# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='https://github.com/udacity/pytorch_challenge/blob/master/assets/Flowers.png?raw=1' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Download the dataset and unzip
# !wget https://s3.amazonaws.com/content.udacity-data.com/courses/nd188/flower_data.zip
  
# !unzip -qq -o "flower_data.zip"
# Out:
# --2018-12-20 18:26:43--  https://s3.amazonaws.com/content.udacity-data.com/courses/nd188/flower_data.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.164.221
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.164.221|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 311442766 (297M) [application/zip]
# Saving to: ‘flower_data.zip’
#
# flower_data.zip     100%[===================>] 297.01M  36.8MB/s    in 8.6s
#
# 2018-12-20 18:26:52 (34.3 MB/s) - ‘flower_data.zip’ saved [311442766/311442766]

# %%
#getting the mapping json file from github
# !wget https://raw.githubusercontent.com/udacity/pytorch_challenge/master/cat_to_name.json
# Out:
# --2018-12-20 18:26:58--  https://raw.githubusercontent.com/udacity/pytorch_challenge/master/cat_to_name.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2218 (2.2K) [text/plain]
# Saving to: ‘cat_to_name.json’
#
# cat_to_name.json    100%[===================>]   2.17K  --.-KB/s    in 0s
#
# 2018-12-20 18:26:59 (21.4 MB/s) - ‘cat_to_name.json’ saved [2218/2218]

# %%
# http://pytorch.org/
from os.path import exists
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision
import torch

# %%
# !pip install Pillow==4.0.0
# !pip install PIL
# !pip install image
# Out:
# Collecting Pillow==4.0.0
#   Using cached https://files.pythonhosted.org/packages/37/e8/b3fbf87b0188d22246678f8cd61e23e31caa1769ebc06f1664e2e5fe8a17/Pillow-4.0.0-cp36-cp36m-manylinux1_x86_64.whl
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow==4.0.0) (0.46)
# torchvision 0.2.1 has requirement pillow>=4.1.1, but you'll have pillow 4.0.0 which is incompatible.
# Installing collected packages: Pillow
#   Found existing installation: Pillow 5.3.0
#     Uninstalling Pillow-5.3.0:
#       Successfully uninstalled Pillow-5.3.0
# Successfully installed Pillow-4.0.0
# Collecting PIL
#   Could not find a version that satisfies the requirement PIL (from versions: )
# No matching distribution found for PIL
# Requirement already satisfied: image in /usr/local/lib/python3.6/dist-packages (1.5.27)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from image) (4.0.0)
# Requirement already satisfied: django in /usr/local/lib/python3.6/dist-packages (from image) (2.1.4)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow->image) (0.46)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from django->image) (2018.7)

# %%
#Imports
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn
from torch.optim import lr_scheduler
import time
import copy
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models
import torchvision.models as models
from PIL import Image
import json
from matplotlib.ticker import FormatStrFormatter

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). You can [download the data here](https://s3.amazonaws.com/content.udacity-data.com/courses/nd188/flower_data.zip). The dataset is split into two parts, training and validation. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. If you use a pre-trained network, you'll also need to make sure the input data is resized to 224x224 pixels as required by the networks.
#
# The validation set is used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks available from `torchvision` were trained on the ImageNet dataset where each color channel was normalized separately. For both sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flower_data'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'

# %%
# TODO: Define your transforms for the training and validation sets
training_transforms = transforms.Compose([transforms.Resize(256),
                                       transforms.RandomRotation(30),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406], 
                                                            [0.229, 0.224, 0.225])])
 

validation_transforms = transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], 
                                                           [0.229, 0.224, 0.225])])



# TODO: Load the datasets with ImageFolder
training_data = datasets.ImageFolder(train_dir, transform=training_transforms)
validation_data =datasets.ImageFolder(valid_dir, transform=validation_transforms)
# TODO: Using the image datasets and the trainforms, define the dataloaders
trainingloader =torch.utils.data.DataLoader(training_data, batch_size=64, shuffle=True)
validationloader =torch.utils.data.DataLoader(validation_data, batch_size=64, shuffle=True)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. If you want to talk through it with someone, chat with your fellow students! You can also ask questions on the forums or join the instructors in office hours.
#
# Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.

# %%
# Load a pre-trained network
model = models.resnet50(pretrained=True)
#check model archeticture
model
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.torch/models/resnet50-19c8e357.pth
# 100%|██████████| 102502400/102502400 [00:04<00:00, 24481807.80it/s]
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (avgpool): AvgPool2d(kernel_size=7, stride=1, padding=0)
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
# Freeze parameters so we don't backprop through them
for param in model.parameters():
    param.requires_grad = False
    
#Replace Classifier with our own
from collections import OrderedDict
num_features = model.fc.in_features

classifier = nn.Sequential(OrderedDict([
                              ('fc1', nn.Linear(num_features, 512)),
                              ('relu', nn.ReLU()),
                              ('drpot', nn.Dropout(p=0.5)),
                              ('hidden', nn.Linear(512, 100)),
                              ( 'drpot', nn.Dropout(p=0.5)),
                              ('fc2', nn.Linear(100, 102)),
                              ('output', nn.LogSoftmax(dim=1)),
                              ]))

model.fc = classifier

# %%
#Setting the loss function and the optimizer

criterion = nn.NLLLoss()

optimizer = optim.Adam(model.fc.parameters(), lr=0.001)

# %%
#training the model
epochs = 13
print_every = 5
steps = 0
loss_show=[]

# change to cuda
model.to('cuda')

for e in range(epochs):
    running_loss = 0
    for ii, (inputs, labels) in enumerate(trainingloader):
        steps += 1
        
        inputs,labels = inputs.to('cuda'), labels.to('cuda')
        
        optimizer.zero_grad()
        
        # Forward and backward passes
        outputs = model.forward(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        
        if steps % print_every == 0:
            model.eval()
            vlost = 0
            accuracy=0
            
            
            for ii, (inputs2,labels2) in enumerate(validationloader):
                optimizer.zero_grad()
                
                inputs2, labels2 = inputs2.to('cuda:0') , labels2.to('cuda:0')
                model.to('cuda:0')
                with torch.no_grad():    
                    outputs = model.forward(inputs2)
                    vlost = criterion(outputs,labels2)
                    ps = torch.exp(outputs).data
                    equality = (labels2.data == ps.max(1)[1])
                    accuracy += equality.type_as(torch.FloatTensor()).mean()
                    
            vlost = vlost / len(validationloader)
            accuracy = accuracy /len(validationloader)
            
                    
            
            print("Epoch: {}/{}... ".format(e+1, epochs),
                  "Loss: {:.4f}".format(running_loss/print_every),
                  "Validation Lost {:.4f}".format(vlost),
                   "Accuracy: {:.4f}".format(accuracy))
            
            
            running_loss = 0
# Out:
# Epoch: 1/13...  Loss: 4.6843 Validation Lost 0.3577 Accuracy: 0.0156
# Epoch: 1/13...  Loss: 4.5557 Validation Lost 0.3598 Accuracy: 0.0439
# Epoch: 1/13...  Loss: 4.4417 Validation Lost 0.3114 Accuracy: 0.0558
# Epoch: 1/13...  Loss: 4.2313 Validation Lost 0.3075 Accuracy: 0.1764
# Epoch: 1/13...  Loss: 4.0695 Validation Lost 0.2924 Accuracy: 0.1639
# Epoch: 1/13...  Loss: 3.8475 Validation Lost 0.2549 Accuracy: 0.2451
# Epoch: 1/13...  Loss: 3.7408 Validation Lost 0.2530 Accuracy: 0.2822
# Epoch: 1/13...  Loss: 3.5300 Validation Lost 0.2816 Accuracy: 0.2743
# Epoch: 1/13...  Loss: 3.1780 Validation Lost 0.2430 Accuracy: 0.3188
# Epoch: 1/13...  Loss: 3.0841 Validation Lost 0.2238 Accuracy: 0.3433
# Epoch: 1/13...  Loss: 2.9134 Validation Lost 0.1903 Accuracy: 0.3894
# Epoch: 1/13...  Loss: 2.6626 Validation Lost 0.1607 Accuracy: 0.4121
# Epoch: 1/13...  Loss: 2.7008 Validation Lost 0.1939 Accuracy: 0.4363
# Epoch: 1/13...  Loss: 2.4199 Validation Lost 0.1700 Accuracy: 0.5163
# Epoch: 1/13...  Loss: 2.2114 Validation Lost 0.1495 Accuracy: 0.4660
# Epoch: 1/13...  Loss: 2.2647 Validation Lost 0.1445 Accuracy: 0.4720
# Epoch: 1/13...  Loss: 2.2291 Validation Lost 0.1439 Accuracy: 0.5598
# Epoch: 1/13...  Loss: 1.9409 Validation Lost 0.1252 Accuracy: 0.5470
# Epoch: 1/13...  Loss: 1.8923 Validation Lost 0.1276 Accuracy: 0.5556
# Epoch: 2/13...  Loss: 0.6763 Validation Lost 0.1477 Accuracy: 0.5568
# Epoch: 2/13...  Loss: 1.6629 Validation Lost 0.1226 Accuracy: 0.5924
# Epoch: 2/13...  Loss: 1.6974 Validation Lost 0.1000 Accuracy: 0.6169
# Epoch: 2/13...  Loss: 1.6147 Validation Lost 0.0783 Accuracy: 0.6124
# Epoch: 2/13...  Loss: 1.6547 Validation Lost 0.1029 Accuracy: 0.6675
# Epoch: 2/13...  Loss: 1.4686 Validation Lost 0.0818 Accuracy: 0.6318
# Epoch: 2/13...  Loss: 1.4427 Validation Lost 0.1009 Accuracy: 0.6802
# Epoch: 2/13...  Loss: 1.3755 Validation Lost 0.0919 Accuracy: 0.7062
# Epoch: 2/13...  Loss: 1.3914 Validation Lost 0.0831 Accuracy: 0.7206
# Epoch: 2/13...  Loss: 1.2902 Validation Lost 0.0621 Accuracy: 0.7118
# Epoch: 2/13...  Loss: 1.2791 Validation Lost 0.0737 Accuracy: 0.7235
# Epoch: 2/13...  Loss: 1.3793 Validation Lost 0.0771 Accuracy: 0.6581
# Epoch: 2/13...  Loss: 1.4127 Validation Lost 0.0902 Accuracy: 0.6977
# Epoch: 2/13...  Loss: 1.3022 Validation Lost 0.0753 Accuracy: 0.6948
# Epoch: 2/13...  Loss: 1.2513 Validation Lost 0.0697 Accuracy: 0.7348
# Epoch: 2/13...  Loss: 1.2068 Validation Lost 0.0606 Accuracy: 0.6925
# Epoch: 2/13...  Loss: 1.1149 Validation Lost 0.0843 Accuracy: 0.7359
# Epoch: 2/13...  Loss: 1.0877 Validation Lost 0.0527 Accuracy: 0.7822
# Epoch: 2/13...  Loss: 1.1548 Validation Lost 0.0555 Accuracy: 0.7415
# Epoch: 2/13...  Loss: 1.1265 Validation Lost 0.0517 Accuracy: 0.7430
# Epoch: 2/13...  Loss: 1.1501 Validation Lost 0.0677 Accuracy: 0.7625
# Epoch: 3/13...  Loss: 0.7536 Validation Lost 0.0394 Accuracy: 0.7573
# Epoch: 3/13...  Loss: 0.9611 Validation Lost 0.0366 Accuracy: 0.7605
# Epoch: 3/13...  Loss: 1.0641 Validation Lost 0.0615 Accuracy: 0.7779
# Epoch: 3/13...  Loss: 1.1137 Validation Lost 0.0512 Accuracy: 0.7719
# Epoch: 3/13...  Loss: 0.9746 Validation Lost 0.0468 Accuracy: 0.7767
# Epoch: 3/13...  Loss: 0.7834 Validation Lost 0.0492 Accuracy: 0.7868
# Epoch: 3/13...  Loss: 0.9353 Validation Lost 0.0400 Accuracy: 0.7978
# Epoch: 3/13...  Loss: 1.0202 Validation Lost 0.0694 Accuracy: 0.8080
# Epoch: 3/13...  Loss: 0.9371 Validation Lost 0.0635 Accuracy: 0.7755
# Epoch: 3/13...  Loss: 0.9704 Validation Lost 0.0472 Accuracy: 0.7758
# Epoch: 3/13...  Loss: 1.0602 Validation Lost 0.0410 Accuracy: 0.7816
# Epoch: 3/13...  Loss: 0.9289 Validation Lost 0.0529 Accuracy: 0.8026
# Epoch: 3/13...  Loss: 0.9950 Validation Lost 0.0477 Accuracy: 0.7938
# Epoch: 3/13...  Loss: 0.9102 Validation Lost 0.0586 Accuracy: 0.8151
# Epoch: 3/13...  Loss: 0.8020 Validation Lost 0.0282 Accuracy: 0.8252
# Epoch: 3/13...  Loss: 0.9349 Validation Lost 0.0394 Accuracy: 0.7834
# Epoch: 3/13...  Loss: 0.9428 Validation Lost 0.0380 Accuracy: 0.8057
# Epoch: 3/13...  Loss: 0.7156 Validation Lost 0.0417 Accuracy: 0.8270
# Epoch: 3/13...  Loss: 0.6655 Validation Lost 0.0443 Accuracy: 0.8260
# Epoch: 3/13...  Loss: 0.9416 Validation Lost 0.0419 Accuracy: 0.8074
# Epoch: 4/13...  Loss: 0.1768 Validation Lost 0.0292 Accuracy: 0.7861
# Epoch: 4/13...  Loss: 0.8359 Validation Lost 0.0365 Accuracy: 0.8174
# Epoch: 4/13...  Loss: 0.7849 Validation Lost 0.0365 Accuracy: 0.8041
# Epoch: 4/13...  Loss: 0.7638 Validation Lost 0.0638 Accuracy: 0.8361
# Epoch: 4/13...  Loss: 0.8698 Validation Lost 0.0474 Accuracy: 0.8425
# Epoch: 4/13...  Loss: 0.8485 Validation Lost 0.0435 Accuracy: 0.8429
# Epoch: 4/13...  Loss: 0.7006 Validation Lost 0.0352 Accuracy: 0.8465
# Epoch: 4/13...  Loss: 0.7548 Validation Lost 0.0646 Accuracy: 0.8050
# Epoch: 4/13...  Loss: 0.8255 Validation Lost 0.0471 Accuracy: 0.8388
# Epoch: 4/13...  Loss: 0.7590 Validation Lost 0.0671 Accuracy: 0.8280
# Epoch: 4/13...  Loss: 0.8148 Validation Lost 0.0369 Accuracy: 0.8285
# Epoch: 4/13...  Loss: 0.8528 Validation Lost 0.0457 Accuracy: 0.8182
# Epoch: 4/13...  Loss: 0.8148 Validation Lost 0.0595 Accuracy: 0.8119
# Epoch: 4/13...  Loss: 0.7391 Validation Lost 0.0251 Accuracy: 0.8364
# Epoch: 4/13...  Loss: 0.7030 Validation Lost 0.0509 Accuracy: 0.8486
# Epoch: 4/13...  Loss: 0.8009 Validation Lost 0.0283 Accuracy: 0.8525
# Epoch: 4/13...  Loss: 0.6815 Validation Lost 0.0391 Accuracy: 0.8399
# Epoch: 4/13...  Loss: 0.8075 Validation Lost 0.0504 Accuracy: 0.8338
# Epoch: 4/13...  Loss: 0.8835 Validation Lost 0.0208 Accuracy: 0.8441
# Epoch: 4/13...  Loss: 0.7844 Validation Lost 0.0464 Accuracy: 0.8335
# Epoch: 4/13...  Loss: 0.7976 Validation Lost 0.0472 Accuracy: 0.8287
# Epoch: 5/13...  Loss: 0.4906 Validation Lost 0.0442 Accuracy: 0.8179
# Epoch: 5/13...  Loss: 0.7538 Validation Lost 0.0365 Accuracy: 0.8122
# Epoch: 5/13...  Loss: 0.7138 Validation Lost 0.0299 Accuracy: 0.8316
# Epoch: 5/13...  Loss: 0.7649 Validation Lost 0.0306 Accuracy: 0.8385
# Epoch: 5/13...  Loss: 0.7128 Validation Lost 0.0402 Accuracy: 0.8479
# Epoch: 5/13...  Loss: 0.7306 Validation Lost 0.0571 Accuracy: 0.8388
# Epoch: 5/13...  Loss: 0.7474 Validation Lost 0.0312 Accuracy: 0.8242
# Epoch: 5/13...  Loss: 0.7638 Validation Lost 0.0455 Accuracy: 0.8299
# Epoch: 5/13...  Loss: 0.7028 Validation Lost 0.0314 Accuracy: 0.8725
# Epoch: 5/13...  Loss: 0.6054 Validation Lost 0.0350 Accuracy: 0.8441
# Epoch: 5/13...  Loss: 0.7876 Validation Lost 0.0349 Accuracy: 0.8393
# Epoch: 5/13...  Loss: 0.8021 Validation Lost 0.0295 Accuracy: 0.8407
# Epoch: 5/13...  Loss: 0.6463 Validation Lost 0.0398 Accuracy: 0.8509
# Epoch: 5/13...  Loss: 0.7893 Validation Lost 0.0343 Accuracy: 0.8714
# Epoch: 5/13...  Loss: 0.6291 Validation Lost 0.0413 Accuracy: 0.8907
# Epoch: 5/13...  Loss: 0.6646 Validation Lost 0.0280 Accuracy: 0.8658
# Epoch: 5/13...  Loss: 0.6416 Validation Lost 0.0579 Accuracy: 0.8654
# Epoch: 5/13...  Loss: 0.5830 Validation Lost 0.0549 Accuracy: 0.8524
# Epoch: 5/13...  Loss: 0.6547 Validation Lost 0.0336 Accuracy: 0.8474
# Epoch: 5/13...  Loss: 0.6810 Validation Lost 0.0720 Accuracy: 0.8582
# Epoch: 5/13...  Loss: 0.6555 Validation Lost 0.0602 Accuracy: 0.8673
# Epoch: 6/13...  Loss: 0.6073 Validation Lost 0.0574 Accuracy: 0.8449
# Epoch: 6/13...  Loss: 0.6216 Validation Lost 0.0589 Accuracy: 0.8449
# Epoch: 6/13...  Loss: 0.7846 Validation Lost 0.0307 Accuracy: 0.8397
# Epoch: 6/13...  Loss: 0.6247 Validation Lost 0.0338 Accuracy: 0.8558
# Epoch: 6/13...  Loss: 0.7002 Validation Lost 0.0249 Accuracy: 0.8517
# Epoch: 6/13...  Loss: 0.6964 Validation Lost 0.0851 Accuracy: 0.8665
# Epoch: 6/13...  Loss: 0.6048 Validation Lost 0.0402 Accuracy: 0.8732
# Epoch: 6/13...  Loss: 0.5736 Validation Lost 0.0368 Accuracy: 0.8718
# Epoch: 6/13...  Loss: 0.5856 Validation Lost 0.0231 Accuracy: 0.8974
# Epoch: 6/13...  Loss: 0.5638 Validation Lost 0.0324 Accuracy: 0.8813
# Epoch: 6/13...  Loss: 0.6954 Validation Lost 0.0308 Accuracy: 0.8426
# Epoch: 6/13...  Loss: 0.6325 Validation Lost 0.0203 Accuracy: 0.8755
# Epoch: 6/13...  Loss: 0.6570 Validation Lost 0.0382 Accuracy: 0.8574
# Epoch: 6/13...  Loss: 0.6345 Validation Lost 0.0348 Accuracy: 0.8591
# Epoch: 6/13...  Loss: 0.5258 Validation Lost 0.0181 Accuracy: 0.8716
# Epoch: 6/13...  Loss: 0.7047 Validation Lost 0.0337 Accuracy: 0.8750
# Epoch: 6/13...  Loss: 0.5282 Validation Lost 0.0276 Accuracy: 0.8489
# Epoch: 6/13...  Loss: 0.7273 Validation Lost 0.0382 Accuracy: 0.8592
# Epoch: 6/13...  Loss: 0.6178 Validation Lost 0.0481 Accuracy: 0.8877
# Epoch: 6/13...  Loss: 0.6236 Validation Lost 0.0357 Accuracy: 0.8694
# Epoch: 7/13...  Loss: 0.2468 Validation Lost 0.0268 Accuracy: 0.8750
# Epoch: 7/13...  Loss: 0.6556 Validation Lost 0.0296 Accuracy: 0.8713
# Epoch: 7/13...  Loss: 0.5490 Validation Lost 0.0278 Accuracy: 0.8847
# Epoch: 7/13...  Loss: 0.5807 Validation Lost 0.0372 Accuracy: 0.8708
# Epoch: 7/13...  Loss: 0.6873 Validation Lost 0.0369 Accuracy: 0.8678
# Epoch: 7/13...  Loss: 0.5173 Validation Lost 0.0436 Accuracy: 0.8871
# Epoch: 7/13...  Loss: 0.5118 Validation Lost 0.0276 Accuracy: 0.8910
# Epoch: 7/13...  Loss: 0.6102 Validation Lost 0.0208 Accuracy: 0.8917
# Epoch: 7/13...  Loss: 0.4492 Validation Lost 0.0237 Accuracy: 0.8745
# Epoch: 7/13...  Loss: 0.6387 Validation Lost 0.0521 Accuracy: 0.8716
# Epoch: 7/13...  Loss: 0.4130 Validation Lost 0.0188 Accuracy: 0.8716
# Epoch: 7/13...  Loss: 0.4686 Validation Lost 0.0325 Accuracy: 0.8704
# Epoch: 7/13...  Loss: 0.6000 Validation Lost 0.0376 Accuracy: 0.8946
# Epoch: 7/13...  Loss: 0.5379 Validation Lost 0.0391 Accuracy: 0.8675
# Epoch: 7/13...  Loss: 0.5725 Validation Lost 0.0300 Accuracy: 0.8606
# Epoch: 7/13...  Loss: 0.5777 Validation Lost 0.0417 Accuracy: 0.8828
# Epoch: 7/13...  Loss: 0.6202 Validation Lost 0.0232 Accuracy: 0.8901
# Epoch: 7/13...  Loss: 0.7358 Validation Lost 0.0205 Accuracy: 0.8733
# Epoch: 7/13...  Loss: 0.6174 Validation Lost 0.0232 Accuracy: 0.8474
# Epoch: 7/13...  Loss: 0.5943 Validation Lost 0.0399 Accuracy: 0.8726
# Epoch: 7/13...  Loss: 0.5526 Validation Lost 0.0360 Accuracy: 0.8886
# Epoch: 8/13...  Loss: 0.3722 Validation Lost 0.0360 Accuracy: 0.8618
# Epoch: 8/13...  Loss: 0.5848 Validation Lost 0.0426 Accuracy: 0.8807
# Epoch: 8/13...  Loss: 0.5120 Validation Lost 0.0189 Accuracy: 0.8721
# Epoch: 8/13...  Loss: 0.4812 Validation Lost 0.0255 Accuracy: 0.8749
# Epoch: 8/13...  Loss: 0.5563 Validation Lost 0.0249 Accuracy: 0.8881
# Epoch: 8/13...  Loss: 0.5437 Validation Lost 0.0587 Accuracy: 0.8821
# Epoch: 8/13...  Loss: 0.4921 Validation Lost 0.0430 Accuracy: 0.8744
# Epoch: 8/13...  Loss: 0.5221 Validation Lost 0.0187 Accuracy: 0.8829
# Epoch: 8/13...  Loss: 0.6608 Validation Lost 0.0425 Accuracy: 0.8706
# Epoch: 8/13...  Loss: 0.5935 Validation Lost 0.0262 Accuracy: 0.8766
# Epoch: 8/13...  Loss: 0.5396 Validation Lost 0.0198 Accuracy: 0.8853
# Epoch: 8/13...  Loss: 0.4752 Validation Lost 0.0579 Accuracy: 0.8855
# Epoch: 8/13...  Loss: 0.5425 Validation Lost 0.0336 Accuracy: 0.8785
# Epoch: 8/13...  Loss: 0.5012 Validation Lost 0.0294 Accuracy: 0.8910
# Epoch: 8/13...  Loss: 0.5278 Validation Lost 0.0125 Accuracy: 0.9004
# Epoch: 8/13...  Loss: 0.5340 Validation Lost 0.0381 Accuracy: 0.8759
# Epoch: 8/13...  Loss: 0.6591 Validation Lost 0.0215 Accuracy: 0.8833
# Epoch: 8/13...  Loss: 0.6330 Validation Lost 0.0398 Accuracy: 0.8747
# Epoch: 8/13...  Loss: 0.5081 Validation Lost 0.0294 Accuracy: 0.9027
# Epoch: 8/13...  Loss: 0.6630 Validation Lost 0.0315 Accuracy: 0.8747
# Epoch: 9/13...  Loss: 0.1170 Validation Lost 0.0335 Accuracy: 0.8865
# Epoch: 9/13...  Loss: 0.6782 Validation Lost 0.0155 Accuracy: 0.8737
# Epoch: 9/13...  Loss: 0.4643 Validation Lost 0.0152 Accuracy: 0.8592
# Epoch: 9/13...  Loss: 0.5072 Validation Lost 0.0133 Accuracy: 0.8872
# Epoch: 9/13...  Loss: 0.6416 Validation Lost 0.0326 Accuracy: 0.8603
# Epoch: 9/13...  Loss: 0.4990 Validation Lost 0.0133 Accuracy: 0.8815
# Epoch: 9/13...  Loss: 0.5051 Validation Lost 0.0308 Accuracy: 0.8797
# Epoch: 9/13...  Loss: 0.5435 Validation Lost 0.0269 Accuracy: 0.8737
# Epoch: 9/13...  Loss: 0.4699 Validation Lost 0.0233 Accuracy: 0.8809
# Epoch: 9/13...  Loss: 0.5647 Validation Lost 0.0277 Accuracy: 0.8865
# Epoch: 9/13...  Loss: 0.4475 Validation Lost 0.0341 Accuracy: 0.8974
# Epoch: 9/13...  Loss: 0.6086 Validation Lost 0.0265 Accuracy: 0.8874
# Epoch: 9/13...  Loss: 0.5111 Validation Lost 0.0310 Accuracy: 0.8814
# Epoch: 9/13...  Loss: 0.5056 Validation Lost 0.0370 Accuracy: 0.8850
# Epoch: 9/13...  Loss: 0.5480 Validation Lost 0.0304 Accuracy: 0.8525
# Epoch: 9/13...  Loss: 0.6263 Validation Lost 0.0523 Accuracy: 0.8613
# Epoch: 9/13...  Loss: 0.3889 Validation Lost 0.0271 Accuracy: 0.8761
# Epoch: 9/13...  Loss: 0.5253 Validation Lost 0.0096 Accuracy: 0.8968
# Epoch: 9/13...  Loss: 0.5656 Validation Lost 0.0219 Accuracy: 0.8778
# Epoch: 9/13...  Loss: 0.4970 Validation Lost 0.0388 Accuracy: 0.8843
# Epoch: 9/13...  Loss: 0.5651 Validation Lost 0.0259 Accuracy: 0.8742
# Epoch: 10/13...  Loss: 0.2601 Validation Lost 0.0213 Accuracy: 0.8773
# Epoch: 10/13...  Loss: 0.5270 Validation Lost 0.0434 Accuracy: 0.8792
# Epoch: 10/13...  Loss: 0.4602 Validation Lost 0.0278 Accuracy: 0.8831
# Epoch: 10/13...  Loss: 0.5278 Validation Lost 0.0243 Accuracy: 0.9094
# Epoch: 10/13...  Loss: 0.5073 Validation Lost 0.0257 Accuracy: 0.8860
# Epoch: 10/13...  Loss: 0.4412 Validation Lost 0.0360 Accuracy: 0.8970
# Epoch: 10/13...  Loss: 0.5186 Validation Lost 0.0402 Accuracy: 0.8740
# Epoch: 10/13...  Loss: 0.5865 Validation Lost 0.0354 Accuracy: 0.8811
# Epoch: 10/13...  Loss: 0.3890 Validation Lost 0.0238 Accuracy: 0.8965
# Epoch: 10/13...  Loss: 0.4471 Validation Lost 0.0287 Accuracy: 0.9118
# Epoch: 10/13...  Loss: 0.5166 Validation Lost 0.0200 Accuracy: 0.8913
# Epoch: 10/13...  Loss: 0.3789 Validation Lost 0.0258 Accuracy: 0.8802
# Epoch: 10/13...  Loss: 0.6086 Validation Lost 0.0444 Accuracy: 0.8963
# Epoch: 10/13...  Loss: 0.5147 Validation Lost 0.0207 Accuracy: 0.8992
# Epoch: 10/13...  Loss: 0.4387 Validation Lost 0.0161 Accuracy: 0.9161
# Epoch: 10/13...  Loss: 0.6629 Validation Lost 0.0115 Accuracy: 0.9191
# Epoch: 10/13...  Loss: 0.3784 Validation Lost 0.0324 Accuracy: 0.8998
# Epoch: 10/13...  Loss: 0.4720 Validation Lost 0.0209 Accuracy: 0.8865
# Epoch: 10/13...  Loss: 0.3806 Validation Lost 0.0185 Accuracy: 0.8920
# Epoch: 10/13...  Loss: 0.4791 Validation Lost 0.0278 Accuracy: 0.8974
# Epoch: 10/13...  Loss: 0.4473 Validation Lost 0.0164 Accuracy: 0.9044
# Epoch: 11/13...  Loss: 0.4148 Validation Lost 0.0402 Accuracy: 0.8907
# Epoch: 11/13...  Loss: 0.4629 Validation Lost 0.0229 Accuracy: 0.9006
# Epoch: 11/13...  Loss: 0.5748 Validation Lost 0.0279 Accuracy: 0.8943
# Epoch: 11/13...  Loss: 0.4336 Validation Lost 0.0356 Accuracy: 0.8694
# Epoch: 11/13...  Loss: 0.4883 Validation Lost 0.0255 Accuracy: 0.9126
# Epoch: 11/13...  Loss: 0.5113 Validation Lost 0.0164 Accuracy: 0.9100
# Epoch: 11/13...  Loss: 0.4879 Validation Lost 0.0218 Accuracy: 0.9001
# Epoch: 11/13...  Loss: 0.5048 Validation Lost 0.0313 Accuracy: 0.9006
# Epoch: 11/13...  Loss: 0.5184 Validation Lost 0.0330 Accuracy: 0.9111
# Epoch: 11/13...  Loss: 0.4639 Validation Lost 0.0203 Accuracy: 0.8980
# Epoch: 11/13...  Loss: 0.4709 Validation Lost 0.0084 Accuracy: 0.9107
# Epoch: 11/13...  Loss: 0.4172 Validation Lost 0.0068 Accuracy: 0.9068
# Epoch: 11/13...  Loss: 0.4319 Validation Lost 0.0306 Accuracy: 0.8998
# Epoch: 11/13...  Loss: 0.3863 Validation Lost 0.0219 Accuracy: 0.9097
# Epoch: 11/13...  Loss: 0.3470 Validation Lost 0.0259 Accuracy: 0.8845
# Epoch: 11/13...  Loss: 0.5299 Validation Lost 0.0505 Accuracy: 0.8860
# Epoch: 11/13...  Loss: 0.5298 Validation Lost 0.0144 Accuracy: 0.9028
# Epoch: 11/13...  Loss: 0.3741 Validation Lost 0.0171 Accuracy: 0.9142
# Epoch: 11/13...  Loss: 0.5365 Validation Lost 0.0292 Accuracy: 0.9066
# Epoch: 11/13...  Loss: 0.5288 Validation Lost 0.0174 Accuracy: 0.9006
# Epoch: 12/13...  Loss: 0.2469 Validation Lost 0.0185 Accuracy: 0.9073
# Epoch: 12/13...  Loss: 0.3432 Validation Lost 0.0352 Accuracy: 0.8936
# Epoch: 12/13...  Loss: 0.4958 Validation Lost 0.0210 Accuracy: 0.8953
# Epoch: 12/13...  Loss: 0.5155 Validation Lost 0.0245 Accuracy: 0.9018
# Epoch: 12/13...  Loss: 0.5667 Validation Lost 0.0142 Accuracy: 0.8908
# Epoch: 12/13...  Loss: 0.4910 Validation Lost 0.0256 Accuracy: 0.8898
# Epoch: 12/13...  Loss: 0.5170 Validation Lost 0.0413 Accuracy: 0.9051
# Epoch: 12/13...  Loss: 0.4283 Validation Lost 0.0268 Accuracy: 0.9030
# Epoch: 12/13...  Loss: 0.3273 Validation Lost 0.0301 Accuracy: 0.8888
# Epoch: 12/13...  Loss: 0.4288 Validation Lost 0.0182 Accuracy: 0.9173
# Epoch: 12/13...  Loss: 0.5193 Validation Lost 0.0174 Accuracy: 0.9236
# Epoch: 12/13...  Loss: 0.3590 Validation Lost 0.0331 Accuracy: 0.9072
# Epoch: 12/13...  Loss: 0.5226 Validation Lost 0.0215 Accuracy: 0.9025
# Epoch: 12/13...  Loss: 0.4444 Validation Lost 0.0229 Accuracy: 0.8893
# Epoch: 12/13...  Loss: 0.5429 Validation Lost 0.0482 Accuracy: 0.9096
# Epoch: 12/13...  Loss: 0.5572 Validation Lost 0.0254 Accuracy: 0.9211
# Epoch: 12/13...  Loss: 0.3900 Validation Lost 0.0228 Accuracy: 0.9130
# Epoch: 12/13...  Loss: 0.4646 Validation Lost 0.0093 Accuracy: 0.9059
# Epoch: 12/13...  Loss: 0.4900 Validation Lost 0.0261 Accuracy: 0.9078
# Epoch: 12/13...  Loss: 0.4952 Validation Lost 0.0169 Accuracy: 0.9088
# Epoch: 12/13...  Loss: 0.4816 Validation Lost 0.0222 Accuracy: 0.8974
# Epoch: 13/13...  Loss: 0.2516 Validation Lost 0.0378 Accuracy: 0.9090
# Epoch: 13/13...  Loss: 0.3918 Validation Lost 0.0589 Accuracy: 0.9123
# Epoch: 13/13...  Loss: 0.3221 Validation Lost 0.0150 Accuracy: 0.8951
# Epoch: 13/13...  Loss: 0.5362 Validation Lost 0.0665 Accuracy: 0.8903
# Epoch: 13/13...  Loss: 0.4477 Validation Lost 0.0275 Accuracy: 0.9054
# Epoch: 13/13...  Loss: 0.4073 Validation Lost 0.0377 Accuracy: 0.8910
# Epoch: 13/13...  Loss: 0.4215 Validation Lost 0.0178 Accuracy: 0.9046
# Epoch: 13/13...  Loss: 0.4327 Validation Lost 0.0261 Accuracy: 0.9034
# Epoch: 13/13...  Loss: 0.4126 Validation Lost 0.0241 Accuracy: 0.8826
# Epoch: 13/13...  Loss: 0.5546 Validation Lost 0.0255 Accuracy: 0.9094
# Epoch: 13/13...  Loss: 0.4824 Validation Lost 0.0228 Accuracy: 0.9040
# Epoch: 13/13...  Loss: 0.5703 Validation Lost 0.0431 Accuracy: 0.9179
# Epoch: 13/13...  Loss: 0.3677 Validation Lost 0.0104 Accuracy: 0.9016
# Epoch: 13/13...  Loss: 0.4189 Validation Lost 0.0092 Accuracy: 0.9200
# Epoch: 13/13...  Loss: 0.4361 Validation Lost 0.0277 Accuracy: 0.9157
# Epoch: 13/13...  Loss: 0.4234 Validation Lost 0.0161 Accuracy: 0.8989
# Epoch: 13/13...  Loss: 0.4755 Validation Lost 0.0574 Accuracy: 0.9197
# Epoch: 13/13...  Loss: 0.4485 Validation Lost 0.0242 Accuracy: 0.9076
# Epoch: 13/13...  Loss: 0.4320 Validation Lost 0.0176 Accuracy: 0.9185
# Epoch: 13/13...  Loss: 0.3653 Validation Lost 0.0188 Accuracy: 0.9112

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
model.class_to_idx = training_data.class_to_idx

model.epochs = epochs
checkpoint = {'input_size': [3, 224, 224],
                 'batch_size': trainingloader.batch_size,
                  'output_size': 102,
                  'state_dict': model.state_dict(),
                  'optimizer_dict':optimizer.state_dict(),
                  'class_to_idx': model.class_to_idx,
                  'epoch': model.epochs}
torch.save(checkpoint, 'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
def load_checkpoint(filepath):
    checkpoint = torch.load(filepath)
    model = models.resnet50()
    
    classifier = nn.Sequential(OrderedDict([
                              ('fc1', nn.Linear(num_features, 512)),
                              ('relu', nn.ReLU()),
                              ('drpot', nn.Dropout(p=0.5)),
                              ('hidden', nn.Linear(512, 100)),
                              ( 'drpot', nn.Dropout(p=0.5)),
                              ('fc2', nn.Linear(100, 102)),
                              ('output', nn.LogSoftmax(dim=1)),
                              ]))
    
    model.fc = classifier
    model.load_state_dict(checkpoint['state_dict'])
    
    return model, checkpoint['class_to_idx']

# get index to class mapping
loaded_model, class_to_idx = load_checkpoint('checkpoint.pth')
idx_to_class = { v : k for k,v in class_to_idx.items()}

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # TODO: Process a PIL image for use in a PyTorch model

    size = 256, 256
    image.thumbnail(size, Image.ANTIALIAS)
    image = image.crop((128 - 112, 128 - 112, 128 + 112, 128 + 112))
    npImage = np.array(image)
    npImage = npImage/255.
        
    imgA = npImage[:,:,0]
    imgB = npImage[:,:,1]
    imgC = npImage[:,:,2]
    
    imgA = (imgA - 0.485)/(0.229) 
    imgB = (imgB - 0.456)/(0.224)
    imgC = (imgC - 0.406)/(0.225)
        
    npImage[:,:,0] = imgA
    npImage[:,:,1] = imgB
    npImage[:,:,2] = imgC
    
    npImage = np.transpose(npImage, (2,0,1))
    
    return npImage

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
    # TODO: Implement the code to predict the class from an image file
    
    image = torch.FloatTensor([process_image(Image.open(image_path))])
    model.eval()
    output = model.forward(image)
    pobabilities = torch.exp(output).data.numpy()[0]
    

    top_idx = np.argsort(pobabilities)[-topk:][::-1] 
    top_class = [idx_to_class[x] for x in top_idx]
    top_probability = pobabilities[top_idx]

    return top_probability, top_class

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the validation accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='https://github.com/udacity/pytorch_challenge/blob/master/assets/inference_example.png?raw=1' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
def view_classify(img, probabilities, classes, mapper):
    ''' Function for viewing an image and it's predicted classes.
    '''
    img_filename = img.split('/')[-2]
    img = Image.open(img)

    fig, (ax1, ax2) = plt.subplots(figsize=(6,10), ncols=1, nrows=2)
    flower_name = mapper[img_filename]
    
    ax1.set_title(flower_name)
    ax1.imshow(img)
    ax1.axis('off')
    
    y_pos = np.arange(len(probabilities))
    ax2.barh(y_pos, probabilities)
    ax2.set_yticks(y_pos)
    ax2.set_yticklabels([mapper[x] for x in classes])
    ax2.invert_yaxis()

# %%
img = 'flower_data/valid/11/image_03100.jpg'
p, c = predict(img, loaded_model)
view_classify(img, p, c, cat_to_name)
